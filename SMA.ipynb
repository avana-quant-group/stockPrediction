# %%
import pandas as pd
import yfinance as yf
import mplfinance as mpf

# %%
TICKER = "AAPL"

df = yf.download(TICKER,start="2022-04-01",end="2022-11-3",auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# df.to_csv(TICKER+'.csv')
# df=pd.read_csv("AAPL.csv")
df=pd.read_csv("aapl.csv",parse_dates=True)

# %%
df
# Out:
#      index        Date        Open        High         Low       Close  \
# 0        0  2022-04-01  173.246241  174.092419  171.165657  173.524979
# 1        1  2022-04-04  173.783802  177.686146  173.654382  177.636368
# 2        2  2022-04-05  176.700620  177.497020  173.634489  174.271606
# 3        3  2022-04-06  171.583764  172.848049  169.363811  171.056152
# 4        4  2022-04-07  170.389164  172.579253  169.085066  171.364746
# ..     ...         ...         ...         ...         ...         ...
# 144    144  2022-10-27  147.824785  148.803157  143.891307  144.560196
# 145    145  2022-10-28  147.954565  157.239166  147.575204  155.482086
# 146    146  2022-10-31  152.906350  153.984563  151.668398  153.086044
# 147    147  2022-11-01  154.823169  155.192551  148.883026  150.400497
# 148    148  2022-11-02  148.703316  151.917985  144.759861  144.789810
#
#         Volume
# 0     78751300
# 1     76468400
# 2     73401800
# 3     89058800
# 4     77594700
# ..         ...
# 144  109180200
# 145  164762400
# 146   97943200
# 147   80379300
# 148   93604600
#
# [149 rows x 7 columns]

# %%
df.head()
newdf = df.reset_index()
newdf.to_csv("aapl.csv", index=False)
# df.to_csv(filename, index=False)

# %%
# df.head()
# df = df.reset_index()

# %%
# mpf.plot(df["2022-04-01":],savefig='static/photo/fi.png')
# mpf.plot(df["2022-04-01":])
df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# numeric_columns = list(df.columns)[1::]
# for column_name in numeric_columns:
#     df[column_name] = df[column_name].str.replace(',', '')
#     df[column_name] = df[column_name].astype(np.float64)
# df.dtypes
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2022-04-01 2022-04-01  173.246226  174.092404  171.165642  173.524963
# 2022-04-04 2022-04-04  173.783802  177.686146  173.654382  177.636368
# 2022-04-05 2022-04-05  176.700605  177.497005  173.634474  174.271591
# 2022-04-06 2022-04-06  171.583764  172.848049  169.363811  171.056152
# 2022-04-07 2022-04-07  170.389164  172.579253  169.085066  171.364746
# ...               ...         ...         ...         ...         ...
# 2022-10-27 2022-10-27  147.824785  148.803157  143.891307  144.560196
# 2022-10-28 2022-10-28  147.954565  157.239166  147.575204  155.482086
# 2022-10-31 2022-10-31  152.906350  153.984563  151.668398  153.086044
# 2022-11-01 2022-11-01  154.823169  155.192551  148.883026  150.400497
# 2022-11-02 2022-11-02  148.703316  151.917985  144.759861  144.789810
#
#                Volume
# Date
# 2022-04-01   78751300
# 2022-04-04   76468400
# 2022-04-05   73401800
# 2022-04-06   89058800
# 2022-04-07   77594700
# ...               ...
# 2022-10-27  109180200
# 2022-10-28  164762400
# 2022-10-31   97943200
# 2022-11-01   80379300
# 2022-11-02   93604600
#
# [149 rows x 6 columns]

# %%
df.index = pd.DatetimeIndex(df['Date'])
extra_plot  = mpf.make_addplot(df.loc["2022-09-01":, ["High","Low"]])
# mpf.plot(df["2022-09-01":], addplot=extra_plot,savefig='static/photo/dowvol.png',volume=True)
mpf.plot(df["2022-09-01":], addplot=extra_plot,volume=True)

# %%
df
# Out:
#             index       Date        Open        High         Low       Close  \
# Date
# 2022-04-01      0 2022-04-01  173.246241  174.092419  171.165657  173.524979
# 2022-04-04      1 2022-04-04  173.783802  177.686146  173.654382  177.636368
# 2022-04-05      2 2022-04-05  176.700620  177.497020  173.634489  174.271606
# 2022-04-06      3 2022-04-06  171.583764  172.848049  169.363811  171.056152
# 2022-04-07      4 2022-04-07  170.389164  172.579253  169.085066  171.364746
# ...           ...        ...         ...         ...         ...         ...
# 2022-10-27    144 2022-10-27  147.824785  148.803157  143.891307  144.560196
# 2022-10-28    145 2022-10-28  147.954565  157.239166  147.575204  155.482086
# 2022-10-31    146 2022-10-31  152.906350  153.984563  151.668398  153.086044
# 2022-11-01    147 2022-11-01  154.823169  155.192551  148.883026  150.400497
# 2022-11-02    148 2022-11-02  148.703316  151.917985  144.759861  144.789810
#
#                Volume
# Date
# 2022-04-01   78751300
# 2022-04-04   76468400
# 2022-04-05   73401800
# 2022-04-06   89058800
# 2022-04-07   77594700
# ...               ...
# 2022-10-27  109180200
# 2022-10-28  164762400
# 2022-10-31   97943200
# 2022-11-01   80379300
# 2022-11-02   93604600
#
# [149 rows x 7 columns]

# %%
# mpf.plot(df["2022-09-01":], type="candle",style="binance",savefig='static/photo/fi2.png')
mpf.plot(df["2022-09-01":], type="candle",style="binance")

# %%
# mpf.plot(df, type="candle", mav=(10,20,30), volume=True,style="binance",savefig='static/photo/movingavg.png')
mpf.plot(df, type="candle", mav=(10,20,30), volume=True,style="yahoo")
