# %%
import pandas as pd
import yfinance as yf
import mplfinance as mpf

# %%
# TICKER = "AAPL"

# df = yf.download(TICKER,start="2022-04-01",end="2022-11-3",auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# df.to_csv(TICKER+'.csv')
# df=pd.read_csv("AAPL.csv")
df=pd.read_csv("static/stock_data/AAPL.csv",parse_dates=True)

# %%
df
# Out:
#             Date        Open        High         Low       Close     Volume
# 0     2016-01-04   23.484397   24.116080   23.344786   24.111502  270597600
# 1     2016-01-05   24.203045   24.225931   23.438618   23.507278  223164000
# 2     2016-01-06   23.015209   23.429466   22.857290   23.047251  273829600
# 3     2016-01-07   22.584929   22.916790   22.069970   22.074547  324377600
# 4     2016-01-08   22.555181   22.683348   22.145503   22.191277  283192000
# ...          ...         ...         ...         ...         ...        ...
# 1728  2022-11-11  145.820007  150.009995  144.369995  149.699997   93903800
# 1729  2022-11-14  148.970001  150.279999  147.429993  148.279999   73374100
# 1730  2022-11-15  152.220001  153.589996  148.559998  150.039993   89868300
# 1731  2022-11-16  149.130005  149.869995  147.289993  148.789993   64218300
# 1732  2022-11-17  146.429993  151.479996  146.149994  150.720001   80389400
#
# [1733 rows x 6 columns]

# %%
# df.head()
# newdf = df.reset_index()
# newdf.to_csv("aapl.csv", index=False)
# # df.to_csv(filename, index=False)

# %%
# df.head()
# df = df.reset_index()

# %%
# mpf.plot(df["2022-04-01":],savefig='static/photo/fi.png')
# mpf.plot(df["2022-04-01":])
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# numeric_columns = list(df.columns)[1::]
# for column_name in numeric_columns:
#     df[column_name] = df[column_name].str.replace(',', '')
#     df[column_name] = df[column_name].astype(np.float64)
# df.dtypes
df2=df.loc['2021-01-01':'2022-01-04']

# %%
df.index = pd.DatetimeIndex(df['Date'])
extra_plot  = mpf.make_addplot(df.loc["2021-09-01":"2022-04-26", ["High","Low"]])
# mpf.plot(df["2022-09-01":], addplot=extra_plot,savefig='static/photo/dowvol.png',volume=True)
mpf.plot(df["2021-09-01":"2022-04-26"], addplot=extra_plot,volume=True)

# %%
df2
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2021-01-04 2021-01-04  131.936187  132.025115  125.256372  127.874939
# 2021-01-05 2021-01-05  127.361130  130.177330  126.906580  129.455978
# 2021-01-06 2021-01-06  126.204984  129.495485  124.880875  125.098267
# 2021-01-07 2021-01-07  126.837389  130.068604  126.343320  129.367020
# 2021-01-08 2021-01-08  130.859110  131.056749  128.685209  130.483627
# ...               ...         ...         ...         ...         ...
# 2021-12-29 2021-12-29  178.295210  179.587712  177.112075  178.344925
# 2021-12-30 2021-12-30  178.434398  179.528057  177.062357  177.171722
# 2021-12-31 2021-12-31  177.062353  178.195774  176.237140  176.545364
# 2022-01-03 2022-01-03  176.803859  181.824722  176.684557  180.959732
# 2022-01-04 2022-01-04  181.576172  181.884380  178.086416  178.663071
#
#                Volume
# Date
# 2021-01-04  143301900
# 2021-01-05   97664900
# 2021-01-06  155088000
# ...

# %%
# mpf.plot(df["2022-09-01":], type="candle",style="binance",savefig='static/photo/fi2.png')
mpf.plot(df["2021-09-01":"2022-04-26"], type="candle",style="binance")

# %%
# mpf.plot(df, type="candle", mav=(10,20,30), volume=True,style="binance",savefig='static/photo/movingavg.png')
mpf.plot(df, type="candle", mav=(10,20,30), volume=True,style="yahoo")
